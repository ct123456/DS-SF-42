# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

#Load File
path_to_file = '../assets/admissions.csv'
admissions = pd.read_csv(path_to_file)
admissions.head()
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
# admit       400 non-null int64
# gre         398 non-null float64
# gpa         398 non-null float64
# prestige    399 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 12.6 KB

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
# admit       400 non-null int64
# gre         398 non-null float64
# gpa         398 non-null float64
# prestige    399 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 12.6 KB

# %%
admissions.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %%
admissions.groupby(["gre"]).size().plot(kind="bar", width=0.85)

# %%
admissions.groupby(["gpa"]).size().plot(kind="bar", width=.75)

# %%
admissions.groupby(["prestige"]).size().plot(kind="bar", width=.85)

# %%
admissions.groupby(["admit"]).size().plot(kind="bar", width=.85)

# %%
prestige = admissions[admissions["prestige"] == 1]
admitted.groupby(["prestige"]).size()
# Out:
# prestige
# 1.0    33
# 2.0    53
# 3.0    28
# 4.0    12
# dtype: int64
